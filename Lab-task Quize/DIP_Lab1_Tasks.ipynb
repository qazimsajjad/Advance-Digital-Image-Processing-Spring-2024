# %% [markdown]
# # Image Processing Lab 1 Tasks

# %% [markdown]
# ## Packages
#
# First, let's run the cell below to import all the packages that you will need during this assignment.
# - [numpy](https://numpy.org/) is the fundamental package for scientific computing with Python.
# - [matplotlib](https://matplotlib.org/) is a famous library to plot graphs in Python.
# - [opencv](https://opencv.org/) is an open-source library for computer vision and image processing tasks in Python.
# - [pandas](https://pandas.pydata.org/) is a powerful open-source library for data manipulation and analysis in Python, providing easy-to-use data structures like DataFrames.

# %%
import numpy as np;
import matplotlib.pyplot as plt;
import pandas as pd;
import cv2;

# %% [markdown]
# ---

# %% [markdown]
# ### Task 1: Image Creation Using Numpy
# #### Part A
# 1. Use `numpy` to create a blank grayscale image (an array of zeros) with height=200 and width=300.
# 2. Display the image using `matplotlib.pyplot.imshow()`.

# %%
# Create blank image here

# %%
# Display the image

# %% [markdown]
# #### Part B
# 1. Create a grayscale image using numpy where every pixel has the same intensity value (e.g., 180).
# 2. Display the image using `matplotlib`.

# %%
# Create and display the image

# %% [markdown]
# #### Part C
# 1. Create an image of shape 200x256 using `numpy` as shown below
# 2. Display the image using `matplotlib`.
#
# ![image.png](attachment:image.png)

# %%
# Create and display the image

# %% [markdown]
# ---

# %% [markdown]
# ### Task 2: Reading an Image
# #### Part A
# 1. Use the `cv2.imread()` function to read an image as a grayscale from your local system.
# 2. Display the image using `matplotlib`.

# %%
## Read and display image here

# %% [markdown]
# #### Part B
# 1. Read the `peppers.jpg` image as a color image using `matplotlib`.
# 2. Display the image using `matplotlib`.
# 3. Extract the Red, Green, and Blue channels and store them in the variables R, G, and B, respectively.
# 4. Display the Red, Green, and Blue channels in a single row using `matplotlib` figure.
#
# *Note that these individual channels are grayscale; you should display them as such.*

# %% [markdown]
# ##### Provide a one-line answer to the following questions:
# 1. Why do red-colored peppers appear white in the Red channel?
# 2. Why do red-colored peppers appear black in the green channel?
# 3. Why do garlic appears white in all three channels?

# %%
# Answer 1

# %%
# Answer 2

# %%
# Answer 3

# %% [markdown]
# #### Part C
# 1. Flip any image upside down without the use of any built-in function
# 2. Display the original image and fliped image in a single row using `matplotlib` figure

# %% [markdown]
# ---

# %% [markdown]
# ### Task 3: Visualizing Image Pixels as a Table
# 1. Read an image as a grayscale image and display it uisng `matplotlib `
# 2. Use numpy to display the pixel matrix.
# 3. Use `pandas.DataFrame()` to display the pixel matrix.
# 4. Print the data type and shape of the image.

# %%
# Read and  dispaly the image

# %%
# Use numpy to display the pixel matrix

# %%
# Use Pandas DataFrame to dispaly the pixel matrix

# %%
# Print shape and data type of image

# %% [markdown]
# ---

# %% [markdown]
# ### Task 3: Image Slicing
# #### Part A
# 1. Read the cricket_ball.jpeg image from the images folder and perform slicing to extract the region containing the ball.
# 2. Display the extracted region.
#
# *Hint: The starting point is (200, 570) and the ending point is (900, 1320).*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Write your code here

# %% [markdown]
# #### Part B
# 1. Create an image using numpy with slicing, as shown below.
# 2. Display the image using `cv2`
#
# *Hint: These are referred to as "true grayscale colors," and there are typically 17 distinct shades that are easily distinguishable by the average human eye.*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Part C
# 1. Create a color image with the specified layout.
# 2. Display the image using cv2.
# 3. Display the image using matplotlib.
#
# ![image.png](attachment:image.png)
#
# Hint:
# - Image shape: (300, 600, 3)
# - Color definitions:
#     - Green: [0, 255, 0]
#     - White: [255, 255, 255]
#     - Blue: [0, 0, 255]
#     - Yellow: [255, 255, 0]
#     - Red: [255, 0, 0]
#     - Black: [0, 0, 0]

# %% [markdown]
# ---

# %% [markdown]
# ## Submission Guidelines:
# - Complete all tasks in the provided cells.
# - Include comments explaining each step of the process.
# - Submit the completed notebook file.
